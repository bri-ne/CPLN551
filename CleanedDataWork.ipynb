# %%
import pandas as pd
import geopandas as gpd

# %%
BGE = pd.read_csv(r'.\BGE.csv')

# %%
BGE.head()
# Out:
#   Route   Direction Pattern             Trip  Trip Code Trip Type Stop Code  \
# 0    16  Southbound      S1  [04:41] 8550076    8550076   Revenue   29964st
# 1    16  Southbound      S1  [05:06] 8550077    8550077   Revenue   29964st
# 2    16  Southbound      S1  [05:25] 8550080    8550080   Revenue   29964st
# 3    16  Southbound      S1  [05:42] 8550078    8550078   Revenue   29964st
# 4    16  Southbound      S1  [05:58] 8550079    8550079   Revenue   29964st
#
#                     Stop Seq.  Avg. Ons  Avg. Offs       Load Dwell Time  \
# 0  (043) - Broad St & Erie Av  0.727273   1.272727  11.363636   00:00:23
# 1  (043) - Broad St & Erie Av  0.500000   1.100000   6.700000   00:00:15
# 2  (043) - Broad St & Erie Av  0.600000   1.400000  11.333333   00:00:13
# 3  (043) - Broad St & Erie Av  0.285714   0.857143   4.785714   00:00:06
# 4  (043) - Broad St & Erie Av  0.294118   1.294118  10.058824   00:00:09
#
# ...

# %%
BGE.sort_values(by= "Avg. Offs", ascending=False)
# Out:
#      Route   Direction Pattern             Trip  Trip Code Trip Type  \
# 1875   BSO  Northbound      N1  [02:52] 8588039    8588039   Revenue
# 1447    XH  Southbound      S1  [21:47] 8591868    8591868   Revenue
# 749     XH  Southbound      S3  [06:42] 8591792    8591792   Revenue
# 524     53  Southbound      S1  [07:40] 8572641    8572641   Revenue
# 1333     H  Southbound      S1  [12:09] 8589058    8589058   Revenue
# ...    ...         ...     ...              ...        ...       ...
# 1296    53  Southbound      S1  [25:40] 8572919    8572919   Revenue
# 1297    53  Southbound      S1  [25:40] 8572919    8572919   Revenue
# 1301   BSO  Southbound      S1  [03:43] 8587970    8587970   Revenue
# 1362     H  Northbound      N1  [06:02] 8589111    8589111   Revenue
# 2021    XH  Northbound      N1  [24:19] 8591981    8591981   Revenue
#
#      Stop Code                           Stop Seq.  Avg. Ons  Avg. Offs  \
# ...
